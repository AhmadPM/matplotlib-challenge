# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sts

# %%
mouse = pd.read_csv('Mouse_metadata.csv')
study = pd.read_csv('Study_results.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d9a8993867e8> in <module>
# ----> 1 mouse = pd.read_csv('Mouse_metadata.csv')
#       2 study = pd.read_csv('Study_results.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Mouse_metadata.csv' does not exist: b'Mouse_metadata.csv'

# %%
mouse.head()

# %%
study.head()
print(study.shape)
print(mouse.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7cb62281cb7e> in <module>
# ----> 1 study.head()
#       2 print(study.shape)
#       3 print(mouse.shape)
#
# NameError: name 'study' is not defined

# %%
df = pd.merge(mouse, study, how='left', on="Mouse ID")

drug = df['Drug Regimen'].value_counts()
drug

df['Drug Regimen'].unique()

drugs = ['Ramicane', 'Capomulin', 'Infubinol', 'Placebo', 'Ceftamin',
       'Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol']

df.head(10)

# %%
grouped = df.groupby(['Drug Regimen'])
grouped.count().head()

# %%
#Generate a summary statistics table consisting of the mean, median, variance, standard deviation, 
#and SEM of the tumor volume for each drug regimen.

tumor_mean = grouped['Tumor Volume (mm3)'].mean()
tumor_median = grouped['Tumor Volume (mm3)'].median()
tumor_std = grouped['Tumor Volume (mm3)'].std()
tumor_sem = grouped['Tumor Volume (mm3)'].sem()

# %%
by_drug = pd.DataFrame({'Avg Tumor Volume': tumor_mean,
                       'Median Tumor Volume': tumor_median,
                        'STD Tumor Volume': tumor_std,
                        'Tumor SEM': tumor_sem
                       
                       })



by_drug.index.name = 'Drug Regimen'


by_drug

# %%
x_axis = np.arange(len(drugs))
tick_locations = [value+0.4 for value in x_axis]

avg = by_drug['Avg Tumor Volume']
med = by_drug['Median Tumor Volume']
std = by_drug['STD Tumor Volume']
sem = by_drug['Tumor SEM']



by_drug.index

# %%
mouse_count = df['Mouse ID'].nunique()
mouse_count

# %%
df.head(10)

# %% [markdown]
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens: Capomulin, Ramicane, Infubinol, and Ceftamin.

# %%
df['Drug Regimen'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-63540ee5376d> in <module>
# ----> 1 df['Drug Regimen'].value_counts()
#
# NameError: name 'df' is not defined

# %%
newdf = df[(df['Drug Regimen'] == 'Capomulin') & (df['Timepoint'] == 45) | (df['Drug Regimen'] == 'Ceftamin') & (df['Timepoint'] == 45) 
           | (df['Drug Regimen'] == 'Infubinol') & (df['Timepoint'] == 45) | 
                (df['Drug Regimen'] == 'Ramicane') & (df['Timepoint'] == 45)]


newdf.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9      k403     Ramicane    Male          21          16         45
# 19     s185    Capomulin  Female           3          17         45
# 29     x401    Capomulin  Female          16          15         45
# 39     m601    Capomulin    Male          22          17         45
# 49     g791     Ramicane    Male          11          16         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 9            22.050126                 1
# 19           23.343598                 1
# 29           28.484033                 0
# 39           28.430964                 1
# 49           29.128472                 1

# %%
newdf = newdf.groupby(['Drug Regimen'])

newdf.head()
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# 59       s508     Ramicane    Male           1          17         45
# 74       m546     Ramicane    Male          18          16         45
# 84       z578     Ramicane    Male          11          16         45
# 104      u364    Capomulin    Male          18          17         45
# 124      y793    Capomulin    Male          17          17         45
# 463      a203    Infubinol  Female          20          23         45
# 473      a251    Infubinol  Female          21          25         45
# 493      a275     Ceftamin  Female          20          28         45
# 540      a685    Infubinol    Male           8          30         45
# 637      c139    Infubinol    Male          11          28         45
# 800      e476    Infubinol    Male          23          26         45
# 993      j296     Ceftamin  Female          24          30         45
# 1033     k210     Ceftamin    Male          15          28         45
# 1112     l471     Ceftamin  Female           7          28         45
# 1132     l661     Ceftamin    Male          18          26         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 9              22.050126                 1
# 19             23.343598                 1
# 29             28.484033                 0
# 39             28.430964                 1
# 49             29.128472                 1
# 59             30.276232                 0
# 74             30.564625                 1
# 84             30.638696                 0
# 104            31.023923                 3
# 124            31.896238                 2
# 463            67.973419                 2
# 473            65.525743                 1
# 493            62.999356                 3
# 540            66.083066                 3
# 637            72.226731                 2
# 800            62.435404                 1
# 993            61.849023                 3
# 1033           68.923185                 3
# 1112           67.748662                 1
# 1132           59.851956                 3

# %%
top_four = ['Capomulin', 'Ceftamin', 'Infubinol', 'Ramicane']


if x in df:
    
    x = df.loc[df['Timepoint'] == 45, 'Tumor Volume (mm3)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-4a40b8e23d20> in <module>
#       2
#       3
# ----> 4 if x in top_four:
#       5     x = df.loc[df['Timepoint'] == 45, 'Tumor Volume (mm3)']
#       6
#
# NameError: name 'x' is not defined

# %%
top_four = by_drug.iloc[[0,1,2,7],:]

top_four
# Out:
#               Avg Tumor Volume  Median Tumor Volume  STD Tumor Volume  \
# Drug Regimen
# Capomulin            40.675741            41.557809          4.994774
# Ceftamin             52.591172            51.776157          6.268188
# Infubinol            52.884795            51.820584          6.567243
# Ramicane             40.216745            40.673236          4.846308
#
#               Tumor SEM
# Drug Regimen
# Capomulin      0.329346
# Ceftamin       0.469821
# Infubinol      0.492236
# Ramicane       0.320955

# %%
# Determine if there are any potential outliers in the average occupancy in California
quartiles = c['AveOccup'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of occupancy is: {lowerq}")
print(f"The upper quartile of occupancy is: {upperq}")
print(f"The interquartile range of occupancy is: {iqr}")
print(f"The the median of occupancy is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")

outlier_cond = (california_data['AveOccup'] < lower_bound) | (california_data['AveOccup'] > upper_bound)
outlier_occupancy = california_data.loc[outlier_cond]
print()
print(outlier_occupancy.shape)
outlier_occupancy.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-2949450856d0> in <module>
#       1 # Determine if there are any potential outliers in the average occupancy in California
# ----> 2 quartiles = c['AveOccup'].quantile([.25,.5,.75])
#       3 lowerq = quartiles[0.25]
#       4 upperq = quartiles[0.75]
#       5 iqr = upperq-lowerq
#
# NameError: name 'c' is not defined
